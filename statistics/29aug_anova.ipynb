# %% [markdown]
# Parametric and non parametric
# ![image.png](attachment:7e606b53-46a4-4852-98b1-b570aae8a200.png)

# %% [markdown]
# ![image.png](attachment:7d17aaa5-f137-4c7e-b84b-c7c9130b03a8.png)

# %%
Selection of

# %% [markdown]
# Selection of the test
#
# ![1_NILL_3EnEckFsQ6Hy06EHg.png](attachment:e4ffa96a-1c8b-4051-a6ea-6615d704c331.png)

# %%
ANOVA: Analysis of variance

Anova enables us to test for significance of difference among more than 2 sample means

1. samples follow normal distribution
2. samples have been selected randomly and independently
3. each group have common variance
4. data are independent
# Out:
#   Cell In[6], line 1
#     ANOVA: Analysis of variance
#                     ^
# SyntaxError: invalid syntax

# %%
Ho : Mean for all the groups are same
Ho : 
Ha : Mean is different for at least one pair of groups
Ha :

# %%
F distribution
    
    It is skewed to the right
    values of F>0
    shape of the f dist is det by 
        dof of num
        dof of den

# %%
When to use anova and t test

# %%
anova = variance between/within between

variance between/variance within > 1 reject
variance between/variance within < 1 fail to reject
variance between/variance within = 1 fail to reject

# %%
python program titanic

# %%
manual calculation:
    group variation = sum all (no of elements * (mean of the group - overall mean)^2)
    within variation = sum all (xi - mean)^2 : for all the groups
    group a var + group b var ....

# %%
Intiuition
    If anova higher - fstatistics would be higher thus lower p value

# %%
It is an extension of t test:
    if we have more than 2 sample mean

# %%
ANOVA is omnibus
    why is it called omnibus test

# %%
post-hoc test(meaning after)
    when we reject null hypothesis

# %%
Equal variances and equal sample sizes: Tukey’s HSD.
Equal variances, unequal sample sizes: Scheffé, Bonferroni.
Unequal variances: Games-Howell.
Comparing to a control group: Dunnett’s Test.
Few comparisons with a focus on power: Fisher’s LSD.

# %%
bonferroni 
bonferroni adjusted alpha  = alpha/no of samples
now these new alpha value would be used to check for all the different groups
