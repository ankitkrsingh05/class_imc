# %%
y = f(x)
price = f(area)

# %%
linear regression is the statistical machine learning algorithm which aims to find the best fit line for the data

# %% [markdown]
# ![residual_sum_of_squares.svg](attachment:1415a8f2-a6c3-40b5-8414-805a3eb89d62.svg)

# %%
reasons of squaring the distance:
1. negative values 
2. we want to penalize the error
3. to make the residual function/loss function differenciable

# %%
independent features:
features used to predict the values/column values/parameters
dependent features:
which is dependent on the independent features / the value which is to be predicted

# %%
We have to find out the value of m(slope) and b (intercept)
such that the SSE is minimum

# %%
If we want to minimize any function,we differentiate the function:

Soo here in our case we want to find the minimun of SSE, 
we will do partial differention on m and b
This would give me the values of m and b when we equate it to zero

# %%
Minimization algorithm:
    OLS:
    Gradient Descent:
